# %% [markdown]
# # Pandas DataFrame
#     Pandas dataframe extends numpy two-dimensional arrays by giving labels to the columns and in case explicit indices are provided to the rows as well
# ## Learning Objectives
#     1. Creating DataFrames from Series objects
#     2. Reading DataFrames from an external file...
#     3. Setting Indexes
#     4. Numeric Operations for Selecting, combining, and creating colums
#     5. Concatenate dataframes
#     6. How to iterate over a dataframe's items
#     7. Drop and inplace

# %%
# imports, follow the conventions...
import numpy as np
import pandas as pd

# %% [markdown]
# ## Creating a DataFrame from series
#     Note: This way of creating dataframes is not common!

# %%
# creating from two series objects
pop2020 = pd.Series([99.9, 91.3, 99.4, 100, 83, 72.4, 84.5, 96.5, 84.8, 76.2],
                    index=['Java','C','C++','Python','C#','PHP','JavaScript','Ruby','R','Matlab'], name='2014')
pop2021 = pd.Series({"C" : 99.9, "C#" : 91.3, "C++" : 99.4, "Java" : 92, "JavaScript" : 83, 
                     "Matlab" : 53, "PHP" : 83, "Python" : 100, "R" : 84.8, "Ruby" : 76.2}, name='2015')
programming_languages_popularity_df = pd.DataFrame({'2020':pop2020, '2021':pop2021})
print("keys of the above dictionary are used as column names")
programming_languages_popularity_df
# Out:
# keys of the above dictionary are used as column names
#              2020   2021
# C            91.3   99.9
# C#           83.0   91.3
# C++          99.4   99.4
# Java         99.9   92.0
# JavaScript   84.5   83.0
# Matlab       76.2   53.0
# PHP          72.4   83.0
# Python      100.0  100.0
# R            84.8   84.8
# Ruby         96.5   76.2

# %% [markdown]
# # Reading DataFrames from an external file...
#     Note: This is the most common way of reading dataframes, which I'm aware of...

# %%
file_path = "files/programming_languages_popularity.csv"
# file_path = r"C:\Users\pooya\projects\PythonSchool\files\programming_languages_popularity.csv"
# column one or column at index zero is used as index!
popularity_df = pd.read_csv(file_path, index_col=0)
popularity_df
# Out:
#              2020   2021   2022
# C            95.5   99.9   98.0
# C#           95.5   91.3   90.0
# C++          95.5   99.4   99.5
# Java         95.0   92.0   91.0
# JavaScript   84.5   83.0   83.0
# Matlab       56.0   53.0   49.0
# PHP          84.8   83.0   86.0
# Python      100.0  100.0  100.0
# R            74.3   84.8   85.0
# Ruby         78.9   76.2   80.0

# %%
print("extracting array values: ")
popularity_df.values
# Out:
# extracting array values:
# array([[ 95.5,  99.9,  98. ],
#        [ 95.5,  91.3,  90. ],
#        [ 95.5,  99.4,  99.5],
#        [ 95. ,  92. ,  91. ],
#        [ 84.5,  83. ,  83. ],
#        [ 56. ,  53. ,  49. ],
#        [ 84.8,  83. ,  86. ],
#        [100. , 100. , 100. ],
#        [ 74.3,  84.8,  85. ],
#        [ 78.9,  76.2,  80. ]])

# %%
print("extracting index values")
popularity_df.index
# Out:
# extracting index values
# Index(['C', 'C#', 'C++', 'Java', 'JavaScript', 'Matlab', 'PHP', 'Python', 'R',
#        'Ruby'],
#       dtype='object')

# %%
print("extracting columns")
popularity_df.columns
# Out:
# extracting columns
# Index(['2020', '2021', '2022'], dtype='object')

# %%
print("extracting columns")
popularity_df.keys()
# Out:
# extracting columns
# Index(['2020', '2021', '2022'], dtype='object')

# %%
print("Getting a column")
popularity_df['2020']
# Out:
# Getting a column
# C              95.5
# C#             95.5
# C++            95.5
# Java           95.0
# JavaScript     84.5
# Matlab         56.0
# PHP            84.8
# Python        100.0
# R              74.3
# Ruby           78.9
# Name: 2020, dtype: float64

# %%
# integer location
popularity_df.iloc[0: 2]
# Out:
#     2020  2021  2022
# C   95.5  99.9  98.0
# C#  95.5  91.3  90.0

# %%
# integer location
print("The first slicing is for the indices(first dimension) and the second one is for the columns(second dimension)")
popularity_df.iloc[:5, :2]
# Out:
# The first slicing is for the indices(first dimension) and the second one is for the columns(second dimension)
#             2020  2021
# C           95.5  99.9
# C#          95.5  91.3
# C++         95.5  99.4
# Java        95.0  92.0
# JavaScript  84.5  83.0

# %%
print("Getting a series and then, getting its values using an integer index:")
popularity_df['2020'][0]
# Out:
# Getting a series and then, getting its values using an integer index:
# 95.5

# %% [markdown]
# # Numeric Operations for Selecting, combining, and creating colums

# %%
popularity_df['Average'] = (popularity_df['2020'] + popularity_df['2021'] + popularity_df['2022']) / 3
# head is used to show the by default first 5 rows. Use tail for showing items from the end of file 
popularity_df.head()
# Out:
#             2020  2021  2022    Average
# C           95.5  99.9  98.0  97.800000
# C#          95.5  91.3  90.0  92.266667
# C++         95.5  99.4  99.5  98.133333
# Java        95.0  92.0  91.0  92.666667
# JavaScript  84.5  83.0  83.0  83.500000

# %%
print("Sorting a dataframe based on a column")
popularity_df = popularity_df.sort_values('2020', ascending=False)
popularity_df
# Out:
# Sorting a dataframe based on a column
#              2020   2021   2022     Average
# Python      100.0  100.0  100.0  100.000000
# C            95.5   99.9   98.0   97.800000
# C#           95.5   91.3   90.0   92.266667
# C++          95.5   99.4   99.5   98.133333
# Java         95.0   92.0   91.0   92.666667
# PHP          84.8   83.0   86.0   84.600000
# JavaScript   84.5   83.0   83.0   83.500000
# Ruby         78.9   76.2   80.0   78.366667
# R            74.3   84.8   85.0   81.366667
# Matlab       56.0   53.0   49.0   52.666667

# %%
print("sorting based on more than one column with varying strategies of odering for each of the columns")
print("orders of the columns for sorting matters!")
popularity_df = popularity_df.sort_values(['2020', '2021'], ascending=[1, 0])
popularity_df
# Out:
# sorting based on more than one column with varying strategies of odering for each of the columns
# orders of the columns for sorting matters!
#              2020   2021   2022     Average
# Matlab       56.0   53.0   49.0   52.666667
# R            74.3   84.8   85.0   81.366667
# Ruby         78.9   76.2   80.0   78.366667
# JavaScript   84.5   83.0   83.0   83.500000
# PHP          84.8   83.0   86.0   84.600000
# Java         95.0   92.0   91.0   92.666667
# C            95.5   99.9   98.0   97.800000
# C++          95.5   99.4   99.5   98.133333
# C#           95.5   91.3   90.0   92.266667
# Python      100.0  100.0  100.0  100.000000

# %%
popularity_df.min()
# Out:
# 2020       56.000000
# 2021       53.000000
# 2022       49.000000
# Average    52.666667
# dtype: float64

# %%
# mean over rows
popularity_df.mean(axis=0)
# Out:
# 2020       86.000000
# 2021       86.260000
# 2022       86.150000
# Average    86.136667
# dtype: float64

# %%
# mean over columns
popularity_df.mean(axis=1)
# Out:
# Matlab         52.666667
# R              81.366667
# Ruby           78.366667
# JavaScript     83.500000
# PHP            84.600000
# Java           92.666667
# C              97.800000
# C++            98.133333
# C#             92.266667
# Python        100.000000
# dtype: float64

# %%
# Apply a function along an axis of the DataFrame.
popularity_df.apply(lambda l: l**2 + 10)
# Out:
#                 2020      2021      2022       Average
# Matlab       3146.00   2819.00   2411.00   2783.777778
# R            5530.49   7201.04   7235.00   6630.534444
# Ruby         6235.21   5816.44   6410.00   6151.334444
# JavaScript   7150.25   6899.00   6899.00   6982.250000
# PHP          7201.04   6899.00   7406.00   7167.160000
# Java         9035.00   8474.00   8291.00   8597.111111
# C            9130.25   9990.01   9614.00   9574.840000
# C++          9130.25   9890.36   9910.25   9640.151111
# C#           9130.25   8345.69   8110.00   8523.137778
# Python      10010.00  10010.00  10010.00  10010.000000

# %%
# get info
popularity_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, Matlab to Python
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   2020     10 non-null     float64
#  1   2021     10 non-null     float64
#  2   2022     10 non-null     float64
#  3   Average  10 non-null     float64
# dtypes: float64(4)
# memory usage: 700.0+ bytes

# %%
# change data type of a pandas dataframe!
popularity_df = popularity_df.astype(np.float32)
popularity_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, Matlab to Python
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   2020     10 non-null     float32
#  1   2021     10 non-null     float32
#  2   2022     10 non-null     float32
#  3   Average  10 non-null     float32
# dtypes: float32(4)
# memory usage: 540.0+ bytes

# %%
# get description
popularity_df.describe()
# Out:
#              2020        2021        2022     Average
# count   10.000000   10.000000   10.000000   10.000000
# mean    86.000000   86.259995   86.150002   86.136673
# std     13.493784   14.285439   14.824997   14.004139
# min     56.000000   53.000000   49.000000   52.666668
# 25%     80.300001   83.000000   83.500000   81.900002
# 50%     89.900002   88.050003   88.000000   88.433334
# 75%     95.500000   97.550001   96.250000   96.516668
# max    100.000000  100.000000  100.000000  100.000000

# %%
print("Manipulating the order of columns in a dataframe")
cols = popularity_df.columns.tolist() # get columns
cols = [cols[-1], *cols[0:3]] # reorder them as you desire
popularity_reordered_df = popularity_df[cols] # you are creating another dataframe!
popularity_reordered_df
# Out:
# Manipulating the order of columns in a dataframe
#                Average        2020        2021   2022
# Matlab       52.666668   56.000000   53.000000   49.0
# R            81.366669   74.300003   84.800003   85.0
# Ruby         78.366669   78.900002   76.199997   80.0
# JavaScript   83.500000   84.500000   83.000000   83.0
# PHP          84.599998   84.800003   83.000000   86.0
# Java         92.666664   95.000000   92.000000   91.0
# C            97.800003   95.500000   99.900002   98.0
# C++          98.133331   95.500000   99.400002   99.5
# C#           92.266670   95.500000   91.300003   90.0
# Python      100.000000  100.000000  100.000000  100.0

# %% [markdown]
# ## Concatenate dataframes

# %%
dummy_data_1 = {
        'id':        ['1', '2', '3', '4', '5'],
        'Feature_1': ['A', 'C', 'E', 'G', 'I'],
        'Feature_2': ['B', 'D', 'F', 'H', 'J']
}
df1 = pd.DataFrame(dummy_data_1)
df1
# Out:
#   id Feature_1 Feature_2
# 0  1         A         B
# 1  2         C         D
# 2  3         E         F
# 3  4         G         H
# 4  5         I         J

# %%
dummy_data_2 = {
        'id':        ['6', '7', '8', '9', '10'],
        'Feature_1': ['K', 'M', 'O', 'Q', 'S'],
        'Feature_2': ['L', 'N', 'P', 'R', 'T']}
df2 = pd.DataFrame(dummy_data_2)
df2
# Out:
#    id Feature_1 Feature_2
# 0   6         K         L
# 1   7         M         N
# 2   8         O         P
# 3   9         Q         R
# 4  10         S         T

# %%
dummy_data_3 = {'Feature_3': [12, 13, 14, 15, 16, 17, 15, 12, 13, -1]}
df3 = pd.DataFrame(dummy_data_3)
df3
# Out:
#    Feature_3
# 0         12
# 1         13
# 2         14
# 3         15
# 4         16
# 5         17
# 6         15
# 7         12
# 8         13
# 9         -1

# %% [markdown]
# #### concatenate

# %%
df_row = pd.concat([df1, df2], axis=0)
df_row
# Out:
#    id Feature_1 Feature_2
# 0   1         A         B
# 1   2         C         D
# 2   3         E         F
# 3   4         G         H
# 4   5         I         J
# 0   6         K         L
# 1   7         M         N
# 2   8         O         P
# 3   9         Q         R
# 4  10         S         T

# %%
df_row = df_row.reset_index().set_index("index")
df_row.index.name = ""
df_row
# Out:
#    id Feature_1 Feature_2
#
# 0   1         A         B
# 1   2         C         D
# 2   3         E         F
# 3   4         G         H
# 4   5         I         J
# 0   6         K         L
# 1   7         M         N
# 2   8         O         P
# 3   9         Q         R
# 4  10         S         T

# %%
# reindexes the index 
# df_row = df_row.reset_index()
df_row = pd.concat([df1, df2], axis=0, ignore_index=True)

df_row
# Out:
#    id Feature_1 Feature_2
# 0   1         A         B
# 1   2         C         D
# 2   3         E         F
# 3   4         G         H
# 4   5         I         J
# 5   6         K         L
# 6   7         M         N
# 7   8         O         P
# 8   9         Q         R
# 9  10         S         T

# %%
# concat vertically

pd.concat([df_row, df3], axis=1)
# Out:
#    id Feature_1 Feature_2  Feature_3
# 0   1         A         B         12
# 1   2         C         D         13
# 2   3         E         F         14
# 3   4         G         H         15
# 4   5         I         J         16
# 5   6         K         L         17
# 6   7         M         N         15
# 7   8         O         P         12
# 8   9         Q         R         13
# 9  10         S         T         -1

# %% [markdown]
# ## How to iterate over a dataframe's items

# %%
import pandas as pd
# read a csv file
tips_df = pd.read_csv('files/tips.csv')
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# heads with argument
tips_df.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
# tail with argument
tips_df.tail(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
for column in tips_df:
    print(f"gets the column names: {column}")
# Out:
# gets the column names: total_bill
# gets the column names: tip
# gets the column names: sex
# gets the column names: smoker
# gets the column names: day
# gets the column names: time
# gets the column names: size

# %%
for column in tips_df.values:
    print(f"gets whole the row: {column}")
# Out:
# gets whole the row: [16.99 1.01 'Female' 'No' 'Sun' 'Dinner' 2]
# gets whole the row: [10.34 1.66 'Male' 'No' 'Sun' 'Dinner' 3]
# gets whole the row: [21.01 3.5 'Male' 'No' 'Sun' 'Dinner' 3]
# gets whole the row: [23.68 3.31 'Male' 'No' 'Sun' 'Dinner' 2]
# gets whole the row: [24.59 3.61 'Female' 'No' 'Sun' 'Dinner' 4]
# gets whole the row: [25.29 4.71 'Male' 'No' 'Sun' 'Dinner' 4]
# gets whole the row: [8.77 2.0 'Male' 'No' 'Sun' 'Dinner' 2]
# gets whole the row: [26.88 3.12 'Male' 'No' 'Sun' 'Dinner' 4]
# gets whole the row: [15.04 1.96 'Male' 'No' 'Sun' 'Dinner' 2]
# gets whole the row: [14.78 3.23 'Male' 'No' 'Sun' 'Dinner' 2]
# gets whole the row: [10.27 1.71 'Male' 'No' 'Sun' 'Dinner' 2]
# gets whole the row: [35.26 5.0 'Female' 'No' 'Sun' 'Dinner' 4]
# gets whole the row: [15.42 1.57 'Male' 'No' 'Sun' 'Dinner' 2]
# gets whole the row: [18.43 3.0 'Male' 'No' 'Sun' 'Dinner' 4]
# gets whole the row: [14.83 3.02 'Female' 'No' 'Sun' 'Dinner' 2]
# gets whole the row: [21.58 3.92 'Male' 'No' 'Sun' 'Dinner' 2]
# gets whole the row: [10.33 1.67 'Female' 'No' 'Sun' 'Dinner' 3]
# gets whole the row: [16.29 3.71 'Male' 'No' 'Sun' 'Dinner' 3]
# gets whole the row: [16.97 3.5 'Female' 'No' 'Sun' 'Dinner' 3]
# gets whole the row: [20.65 3.35 'Male' 'No' 'Sat' 'Dinner' 3]
# gets whole the row: [17.92 4.08 'Male' 'No' 'Sat' 'Dinner' 2]
# gets whole the row: [20.29 2.75 'Female' 'No' 'Sat' 'Dinner' 2]
# gets whole the row: [15.77 2.23 'Female' 'No' 'Sat' 'Dinner' 2]
# gets whole the row: [39.42 7.58 'Male' 'No' 'Sat' 'Dinner' 4]
# gets whole the row: [19.82 3.18 'Male' 'No' 'Sat' 'Dinner' 2]
# gets whole the row: [17.81 2.34 'Male' 'No' 'Sat' 'Dinner' 4]
# gets whole the row: [13.37 2.0 'Male' 'No' 'Sat' 'Dinner' 2]
# gets whole the row: [12.69 2.0 'Male' 'No' 'Sat' 'Dinner' 2]
# gets whole the row: [21.7 4.3 'Male' 'No' 'Sat' 'Dinner' 2]
# gets whole the row: [19.65 3.0 'Female' 'No' 'Sat' 'Dinner' 2]
# gets whole the row: [9.55 1.45 'Male' 'No' 'Sat' 'Dinner' 2]
# gets whole the row: [18.35 2.5 'Male' 'No' 'Sat' 'Dinner' 4]
# gets whole the row: [15.06 3.0 'Female' 'No' 'Sat' 'Dinner' 2]
# gets whole the row: [20.69 2.45 'Female' 'No' 'Sat' 'Dinner' 4]
# gets whole the row: [17.78 3.27 'Male' 'No' 'Sat' 'Dinner' 2]
# gets whole the row: [24.06 3.6 'Male' 'No' 'Sat' 'Dinner' 3]
# gets whole the row: [16.31 2.0 'Male' 'No' 'Sat' 'Dinner' 3]
# gets whole the row: [16.93 3.07 'Female' 'No' 'Sat' 'Dinner' 3]
# gets whole the row: [18.69 2.31 'Male' 'No' 'Sat' 'Dinner' 3]
# gets whole the row: [31.27 5.0 'Male' 'No' 'Sat' 'Dinner' 3]
# gets whole the row: [16.04 2.24 'Male' 'No' 'Sat' 'Dinner' 3]
# gets whole the row: [17.46 2.54 'Male' 'No' 'Sun' 'Dinner' 2]
# gets whole the row: [13.94 3.06 'Male' 'No' 'Sun' 'Dinner' 2]
# gets whole the row: [9.68 1.32 'Male' 'No' 'Sun' 'Dinner' 2]
# gets whole the row: [30.4 5.6 'Male' 'No' 'Sun' 'Dinner' 4]
# gets whole the row: [18.29 3.0 'Male' 'No' 'Sun' 'Dinner' 2]
# gets whole the row: [22.23 5.0 'Male' 'No' 'Sun' 'Dinner' 2]
# gets whole the row: [32.4 6.0 'Male' 'No' 'Sun' 'Dinner' 4]
# gets whole the row: [28.55 2.05 'Male' 'No' 'Sun' 'Dinner' 3]
# gets whole the row: [18.04 3.0 'Male' 'No' 'Sun' 'Dinner' 2]
# gets whole the row: [12.54 2.5 'Male' 'No' 'Sun' 'Dinner' 2]
# gets whole the row: [10.29 2.6 'Female' 'No' 'Sun' 'Dinner' 2]
# gets whole the row: [34.81 5.2 'Female' 'No' 'Sun' 'Dinner' 4]
# gets whole the row: [9.94 1.56 'Male' 'No' 'Sun' 'Dinner' 2]
# gets whole the row: [25.56 4.34 'Male' 'No' 'Sun' 'Dinner' 4]
# gets whole the row: [19.49 3.51 'Male' 'No' 'Sun' 'Dinner' 2]
# gets whole the row: [38.01 3.0 'Male' 'Yes' 'Sat' 'Dinner' 4]
# gets whole the row: [26.41 1.5 'Female' 'No' 'Sat' 'Dinner' 2]
# gets whole the row: [11.24 1.76 'Male' 'Yes' 'Sat' 'Dinner' 2]
# gets whole the row: [48.27 6.73 'Male' 'No' 'Sat' 'Dinner' 4]
# gets whole the row: [20.29 3.21 'Male' 'Yes' 'Sat' 'Dinner' 2]
# gets whole the row: [13.81 2.0 'Male' 'Yes' 'Sat' 'Dinner' 2]
# gets whole the row: [11.02 1.98 'Male' 'Yes' 'Sat' 'Dinner' 2]
# gets whole the row: [18.29 3.76 'Male' 'Yes' 'Sat' 'Dinner' 4]
# gets whole the row: [17.59 2.64 'Male' 'No' 'Sat' 'Dinner' 3]
# gets whole the row: [20.08 3.15 'Male' 'No' 'Sat' 'Dinner' 3]
# gets whole the row: [16.45 2.47 'Female' 'No' 'Sat' 'Dinner' 2]
# gets whole the row: [3.07 1.0 'Female' 'Yes' 'Sat' 'Dinner' 1]
# gets whole the row: [20.23 2.01 'Male' 'No' 'Sat' 'Dinner' 2]
# gets whole the row: [15.01 2.09 'Male' 'Yes' 'Sat' 'Dinner' 2]
# gets whole the row: [12.02 1.97 'Male' 'No' 'Sat' 'Dinner' 2]
# gets whole the row: [17.07 3.0 'Female' 'No' 'Sat' 'Dinner' 3]
# gets whole the row: [26.86 3.14 'Female' 'Yes' 'Sat' 'Dinner' 2]
# gets whole the row: [25.28 5.0 'Female' 'Yes' 'Sat' 'Dinner' 2]
# gets whole the row: [14.73 2.2 'Female' 'No' 'Sat' 'Dinner' 2]
# gets whole the row: [10.51 1.25 'Male' 'No' 'Sat' 'Dinner' 2]
# gets whole the row: [17.92 3.08 'Male' 'Yes' 'Sat' 'Dinner' 2]
# gets whole the row: [27.2 4.0 'Male' 'No' 'Thur' 'Lunch' 4]
# gets whole the row: [22.76 3.0 'Male' 'No' 'Thur' 'Lunch' 2]
# gets whole the row: [17.29 2.71 'Male' 'No' 'Thur' 'Lunch' 2]
# gets whole the row: [19.44 3.0 'Male' 'Yes' 'Thur' 'Lunch' 2]
# gets whole the row: [16.66 3.4 'Male' 'No' 'Thur' 'Lunch' 2]
# gets whole the row: [10.07 1.83 'Female' 'No' 'Thur' 'Lunch' 1]
# gets whole the row: [32.68 5.0 'Male' 'Yes' 'Thur' 'Lunch' 2]
# gets whole the row: [15.98 2.03 'Male' 'No' 'Thur' 'Lunch' 2]
# gets whole the row: [34.83 5.17 'Female' 'No' 'Thur' 'Lunch' 4]
# gets whole the row: [13.03 2.0 'Male' 'No' 'Thur' 'Lunch' 2]
# gets whole the row: [18.28 4.0 'Male' 'No' 'Thur' 'Lunch' 2]
# gets whole the row: [24.71 5.85 'Male' 'No' 'Thur' 'Lunch' 2]
# gets whole the row: [21.16 3.0 'Male' 'No' 'Thur' 'Lunch' 2]
# gets whole the row: [28.97 3.0 'Male' 'Yes' 'Fri' 'Dinner' 2]
# gets whole the row: [22.49 3.5 'Male' 'No' 'Fri' 'Dinner' 2]
# gets whole the row: [5.75 1.0 'Female' 'Yes' 'Fri' 'Dinner' 2]
# gets whole the row: [16.32 4.3 'Female' 'Yes' 'Fri' 'Dinner' 2]
# gets whole the row: [22.75 3.25 'Female' 'No' 'Fri' 'Dinner' 2]
# gets whole the row: [40.17 4.73 'Male' 'Yes' 'Fri' 'Dinner' 4]
# gets whole the row: [27.28 4.0 'Male' 'Yes' 'Fri' 'Dinner' 2]
# gets whole the row: [12.03 1.5 'Male' 'Yes' 'Fri' 'Dinner' 2]
# gets whole the row: [21.01 3.0 'Male' 'Yes' 'Fri' 'Dinner' 2]
# gets whole the row: [12.46 1.5 'Male' 'No' 'Fri' 'Dinner' 2]
# gets whole the row: [11.35 2.5 'Female' 'Yes' 'Fri' 'Dinner' 2]
# gets whole the row: [15.38 3.0 'Female' 'Yes' 'Fri' 'Dinner' 2]
# gets whole the row: [44.3 2.5 'Female' 'Yes' 'Sat' 'Dinner' 3]
# gets whole the row: [22.42 3.48 'Female' 'Yes' 'Sat' 'Dinner' 2]
# gets whole the row: [20.92 4.08 'Female' 'No' 'Sat' 'Dinner' 2]
# gets whole the row: [15.36 1.64 'Male' 'Yes' 'Sat' 'Dinner' 2]
# gets whole the row: [20.49 4.06 'Male' 'Yes' 'Sat' 'Dinner' 2]
# gets whole the row: [25.21 4.29 'Male' 'Yes' 'Sat' 'Dinner' 2]
# gets whole the row: [18.24 3.76 'Male' 'No' 'Sat' 'Dinner' 2]
# gets whole the row: [14.31 4.0 'Female' 'Yes' 'Sat' 'Dinner' 2]
# gets whole the row: [14.0 3.0 'Male' 'No' 'Sat' 'Dinner' 2]
# gets whole the row: [7.25 1.0 'Female' 'No' 'Sat' 'Dinner' 1]
# gets whole the row: [38.07 4.0 'Male' 'No' 'Sun' 'Dinner' 3]
# gets whole the row: [23.95 2.55 'Male' 'No' 'Sun' 'Dinner' 2]
# gets whole the row: [25.71 4.0 'Female' 'No' 'Sun' 'Dinner' 3]
# gets whole the row: [17.31 3.5 'Female' 'No' 'Sun' 'Dinner' 2]
# gets whole the row: [29.93 5.07 'Male' 'No' 'Sun' 'Dinner' 4]
# gets whole the row: [10.65 1.5 'Female' 'No' 'Thur' 'Lunch' 2]
# gets whole the row: [12.43 1.8 'Female' 'No' 'Thur' 'Lunch' 2]
# gets whole the row: [24.08 2.92 'Female' 'No' 'Thur' 'Lunch' 4]
# gets whole the row: [11.69 2.31 'Male' 'No' 'Thur' 'Lunch' 2]
# gets whole the row: [13.42 1.68 'Female' 'No' 'Thur' 'Lunch' 2]
# gets whole the row: [14.26 2.5 'Male' 'No' 'Thur' 'Lunch' 2]
# gets whole the row: [15.95 2.0 'Male' 'No' 'Thur' 'Lunch' 2]
# gets whole the row: [12.48 2.52 'Female' 'No' 'Thur' 'Lunch' 2]
# gets whole the row: [29.8 4.2 'Female' 'No' 'Thur' 'Lunch' 6]
# gets whole the row: [8.52 1.48 'Male' 'No' 'Thur' 'Lunch' 2]
# gets whole the row: [14.52 2.0 'Female' 'No' 'Thur' 'Lunch' 2]
# gets whole the row: [11.38 2.0 'Female' 'No' 'Thur' 'Lunch' 2]
# gets whole the row: [22.82 2.18 'Male' 'No' 'Thur' 'Lunch' 3]
# gets whole the row: [19.08 1.5 'Male' 'No' 'Thur' 'Lunch' 2]
# gets whole the row: [20.27 2.83 'Female' 'No' 'Thur' 'Lunch' 2]
# gets whole the row: [11.17 1.5 'Female' 'No' 'Thur' 'Lunch' 2]
# gets whole the row: [12.26 2.0 'Female' 'No' 'Thur' 'Lunch' 2]
# gets whole the row: [18.26 3.25 'Female' 'No' 'Thur' 'Lunch' 2]
# gets whole the row: [8.51 1.25 'Female' 'No' 'Thur' 'Lunch' 2]
# gets whole the row: [10.33 2.0 'Female' 'No' 'Thur' 'Lunch' 2]
# gets whole the row: [14.15 2.0 'Female' 'No' 'Thur' 'Lunch' 2]
# gets whole the row: [16.0 2.0 'Male' 'Yes' 'Thur' 'Lunch' 2]
# gets whole the row: [13.16 2.75 'Female' 'No' 'Thur' 'Lunch' 2]
# gets whole the row: [17.47 3.5 'Female' 'No' 'Thur' 'Lunch' 2]
# gets whole the row: [34.3 6.7 'Male' 'No' 'Thur' 'Lunch' 6]
# gets whole the row: [41.19 5.0 'Male' 'No' 'Thur' 'Lunch' 5]
# gets whole the row: [27.05 5.0 'Female' 'No' 'Thur' 'Lunch' 6]
# gets whole the row: [16.43 2.3 'Female' 'No' 'Thur' 'Lunch' 2]
# gets whole the row: [8.35 1.5 'Female' 'No' 'Thur' 'Lunch' 2]
# gets whole the row: [18.64 1.36 'Female' 'No' 'Thur' 'Lunch' 3]
# gets whole the row: [11.87 1.63 'Female' 'No' 'Thur' 'Lunch' 2]
# gets whole the row: [9.78 1.73 'Male' 'No' 'Thur' 'Lunch' 2]
# gets whole the row: [7.51 2.0 'Male' 'No' 'Thur' 'Lunch' 2]
# gets whole the row: [14.07 2.5 'Male' 'No' 'Sun' 'Dinner' 2]
# gets whole the row: [13.13 2.0 'Male' 'No' 'Sun' 'Dinner' 2]
# gets whole the row: [17.26 2.74 'Male' 'No' 'Sun' 'Dinner' 3]
# gets whole the row: [24.55 2.0 'Male' 'No' 'Sun' 'Dinner' 4]
# gets whole the row: [19.77 2.0 'Male' 'No' 'Sun' 'Dinner' 4]
# gets whole the row: [29.85 5.14 'Female' 'No' 'Sun' 'Dinner' 5]
# gets whole the row: [48.17 5.0 'Male' 'No' 'Sun' 'Dinner' 6]
# gets whole the row: [25.0 3.75 'Female' 'No' 'Sun' 'Dinner' 4]
# gets whole the row: [13.39 2.61 'Female' 'No' 'Sun' 'Dinner' 2]
# gets whole the row: [16.49 2.0 'Male' 'No' 'Sun' 'Dinner' 4]
# gets whole the row: [21.5 3.5 'Male' 'No' 'Sun' 'Dinner' 4]
# gets whole the row: [12.66 2.5 'Male' 'No' 'Sun' 'Dinner' 2]
# gets whole the row: [16.21 2.0 'Female' 'No' 'Sun' 'Dinner' 3]
# gets whole the row: [13.81 2.0 'Male' 'No' 'Sun' 'Dinner' 2]
# gets whole the row: [17.51 3.0 'Female' 'Yes' 'Sun' 'Dinner' 2]
# gets whole the row: [24.52 3.48 'Male' 'No' 'Sun' 'Dinner' 3]
# gets whole the row: [20.76 2.24 'Male' 'No' 'Sun' 'Dinner' 2]
# gets whole the row: [31.71 4.5 'Male' 'No' 'Sun' 'Dinner' 4]
# gets whole the row: [10.59 1.61 'Female' 'Yes' 'Sat' 'Dinner' 2]
# gets whole the row: [10.63 2.0 'Female' 'Yes' 'Sat' 'Dinner' 2]
# gets whole the row: [50.81 10.0 'Male' 'Yes' 'Sat' 'Dinner' 3]
# gets whole the row: [15.81 3.16 'Male' 'Yes' 'Sat' 'Dinner' 2]
# gets whole the row: [7.25 5.15 'Male' 'Yes' 'Sun' 'Dinner' 2]
# gets whole the row: [31.85 3.18 'Male' 'Yes' 'Sun' 'Dinner' 2]
# gets whole the row: [16.82 4.0 'Male' 'Yes' 'Sun' 'Dinner' 2]
# gets whole the row: [32.9 3.11 'Male' 'Yes' 'Sun' 'Dinner' 2]
# gets whole the row: [17.89 2.0 'Male' 'Yes' 'Sun' 'Dinner' 2]
# gets whole the row: [14.48 2.0 'Male' 'Yes' 'Sun' 'Dinner' 2]
# gets whole the row: [9.6 4.0 'Female' 'Yes' 'Sun' 'Dinner' 2]
# gets whole the row: [34.63 3.55 'Male' 'Yes' 'Sun' 'Dinner' 2]
# gets whole the row: [34.65 3.68 'Male' 'Yes' 'Sun' 'Dinner' 4]
# gets whole the row: [23.33 5.65 'Male' 'Yes' 'Sun' 'Dinner' 2]
# gets whole the row: [45.35 3.5 'Male' 'Yes' 'Sun' 'Dinner' 3]
# gets whole the row: [23.17 6.5 'Male' 'Yes' 'Sun' 'Dinner' 4]
# gets whole the row: [40.55 3.0 'Male' 'Yes' 'Sun' 'Dinner' 2]
# gets whole the row: [20.69 5.0 'Male' 'No' 'Sun' 'Dinner' 5]
# gets whole the row: [20.9 3.5 'Female' 'Yes' 'Sun' 'Dinner' 3]
# gets whole the row: [30.46 2.0 'Male' 'Yes' 'Sun' 'Dinner' 5]
# gets whole the row: [18.15 3.5 'Female' 'Yes' 'Sun' 'Dinner' 3]
# gets whole the row: [23.1 4.0 'Male' 'Yes' 'Sun' 'Dinner' 3]
# gets whole the row: [15.69 1.5 'Male' 'Yes' 'Sun' 'Dinner' 2]
# gets whole the row: [19.81 4.19 'Female' 'Yes' 'Thur' 'Lunch' 2]
# gets whole the row: [28.44 2.56 'Male' 'Yes' 'Thur' 'Lunch' 2]
# gets whole the row: [15.48 2.02 'Male' 'Yes' 'Thur' 'Lunch' 2]
# gets whole the row: [16.58 4.0 'Male' 'Yes' 'Thur' 'Lunch' 2]
# gets whole the row: [7.56 1.44 'Male' 'No' 'Thur' 'Lunch' 2]
# gets whole the row: [10.34 2.0 'Male' 'Yes' 'Thur' 'Lunch' 2]
# gets whole the row: [43.11 5.0 'Female' 'Yes' 'Thur' 'Lunch' 4]
# gets whole the row: [13.0 2.0 'Female' 'Yes' 'Thur' 'Lunch' 2]
# gets whole the row: [13.51 2.0 'Male' 'Yes' 'Thur' 'Lunch' 2]
# gets whole the row: [18.71 4.0 'Male' 'Yes' 'Thur' 'Lunch' 3]
# gets whole the row: [12.74 2.01 'Female' 'Yes' 'Thur' 'Lunch' 2]
# gets whole the row: [13.0 2.0 'Female' 'Yes' 'Thur' 'Lunch' 2]
# gets whole the row: [16.4 2.5 'Female' 'Yes' 'Thur' 'Lunch' 2]
# gets whole the row: [20.53 4.0 'Male' 'Yes' 'Thur' 'Lunch' 4]
# gets whole the row: [16.47 3.23 'Female' 'Yes' 'Thur' 'Lunch' 3]
# gets whole the row: [26.59 3.41 'Male' 'Yes' 'Sat' 'Dinner' 3]
# gets whole the row: [38.73 3.0 'Male' 'Yes' 'Sat' 'Dinner' 4]
# gets whole the row: [24.27 2.03 'Male' 'Yes' 'Sat' 'Dinner' 2]
# gets whole the row: [12.76 2.23 'Female' 'Yes' 'Sat' 'Dinner' 2]
# gets whole the row: [30.06 2.0 'Male' 'Yes' 'Sat' 'Dinner' 3]
# gets whole the row: [25.89 5.16 'Male' 'Yes' 'Sat' 'Dinner' 4]
# gets whole the row: [48.33 9.0 'Male' 'No' 'Sat' 'Dinner' 4]
# gets whole the row: [13.27 2.5 'Female' 'Yes' 'Sat' 'Dinner' 2]
# gets whole the row: [28.17 6.5 'Female' 'Yes' 'Sat' 'Dinner' 3]
# gets whole the row: [12.9 1.1 'Female' 'Yes' 'Sat' 'Dinner' 2]
# gets whole the row: [28.15 3.0 'Male' 'Yes' 'Sat' 'Dinner' 5]
# gets whole the row: [11.59 1.5 'Male' 'Yes' 'Sat' 'Dinner' 2]
# gets whole the row: [7.74 1.44 'Male' 'Yes' 'Sat' 'Dinner' 2]
# gets whole the row: [30.14 3.09 'Female' 'Yes' 'Sat' 'Dinner' 4]
# gets whole the row: [12.16 2.2 'Male' 'Yes' 'Fri' 'Lunch' 2]
# gets whole the row: [13.42 3.48 'Female' 'Yes' 'Fri' 'Lunch' 2]
# gets whole the row: [8.58 1.92 'Male' 'Yes' 'Fri' 'Lunch' 1]
# gets whole the row: [15.98 3.0 'Female' 'No' 'Fri' 'Lunch' 3]
# gets whole the row: [13.42 1.58 'Male' 'Yes' 'Fri' 'Lunch' 2]
# gets whole the row: [16.27 2.5 'Female' 'Yes' 'Fri' 'Lunch' 2]
# gets whole the row: [10.09 2.0 'Female' 'Yes' 'Fri' 'Lunch' 2]
# gets whole the row: [20.45 3.0 'Male' 'No' 'Sat' 'Dinner' 4]
# gets whole the row: [13.28 2.72 'Male' 'No' 'Sat' 'Dinner' 2]
# gets whole the row: [22.12 2.88 'Female' 'Yes' 'Sat' 'Dinner' 2]
# gets whole the row: [24.01 2.0 'Male' 'Yes' 'Sat' 'Dinner' 4]
# gets whole the row: [15.69 3.0 'Male' 'Yes' 'Sat' 'Dinner' 3]
# gets whole the row: [11.61 3.39 'Male' 'No' 'Sat' 'Dinner' 2]
# gets whole the row: [10.77 1.47 'Male' 'No' 'Sat' 'Dinner' 2]
# gets whole the row: [15.53 3.0 'Male' 'Yes' 'Sat' 'Dinner' 2]
# gets whole the row: [10.07 1.25 'Male' 'No' 'Sat' 'Dinner' 2]
# gets whole the row: [12.6 1.0 'Male' 'Yes' 'Sat' 'Dinner' 2]
# gets whole the row: [32.83 1.17 'Male' 'Yes' 'Sat' 'Dinner' 2]
# gets whole the row: [35.83 4.67 'Female' 'No' 'Sat' 'Dinner' 3]
# gets whole the row: [29.03 5.92 'Male' 'No' 'Sat' 'Dinner' 3]
# gets whole the row: [27.18 2.0 'Female' 'Yes' 'Sat' 'Dinner' 2]
# gets whole the row: [22.67 2.0 'Male' 'Yes' 'Sat' 'Dinner' 2]
# gets whole the row: [17.82 1.75 'Male' 'No' 'Sat' 'Dinner' 2]
# gets whole the row: [18.78 3.0 'Female' 'No' 'Thur' 'Dinner' 2]

# %%
for row_index, row in tips_df.iterrows():
#     print(f"gets whole the row: {row_index}, {row}")
    print(f"total bill for row: {row_index} is: {row['total_bill']}")
# Out:
# total bill for row: 0 is: 16.99
# total bill for row: 1 is: 10.34
# total bill for row: 2 is: 21.01
# total bill for row: 3 is: 23.68
# total bill for row: 4 is: 24.59
# total bill for row: 5 is: 25.29
# total bill for row: 6 is: 8.77
# total bill for row: 7 is: 26.88
# total bill for row: 8 is: 15.04
# total bill for row: 9 is: 14.78
# total bill for row: 10 is: 10.27
# total bill for row: 11 is: 35.26
# total bill for row: 12 is: 15.42
# total bill for row: 13 is: 18.43
# total bill for row: 14 is: 14.83
# total bill for row: 15 is: 21.58
# total bill for row: 16 is: 10.33
# total bill for row: 17 is: 16.29
# total bill for row: 18 is: 16.97
# total bill for row: 19 is: 20.65
# total bill for row: 20 is: 17.92
# total bill for row: 21 is: 20.29
# total bill for row: 22 is: 15.77
# total bill for row: 23 is: 39.42
# total bill for row: 24 is: 19.82
# total bill for row: 25 is: 17.81
# total bill for row: 211 is: 25.89
# total bill for row: 212 is: 48.33
# total bill for row: 213 is: 13.27
# total bill for row: 214 is: 28.17
# total bill for row: 215 is: 12.9
# total bill for row: 216 is: 28.15
# total bill for row: 217 is: 11.59
# total bill for row: 218 is: 7.74
# total bill for row: 219 is: 30.14
# total bill for row: 220 is: 12.16
# total bill for row: 221 is: 13.42
# total bill for row: 222 is: 8.58
# total bill for row: 223 is: 15.98
# total bill for row: 224 is: 13.42
# total bill for row: 225 is: 16.27
# total bill for row: 226 is: 10.09
# total bill for row: 227 is: 20.45
# total bill for row: 228 is: 13.28
# total bill for row: 229 is: 22.12
# total bill for row: 230 is: 24.01
# total bill for row: 231 is: 15.69
# total bill for row: 232 is: 11.61
# total bill for row: 233 is: 10.77
# total bill for row: 234 is: 15.53
# total bill for row: 235 is: 10.07
# total bill for row: 236 is: 12.6
# total bill for row: 237 is: 32.83
# total bill for row: 238 is: 35.83
# total bill for row: 239 is: 29.03
# total bill for row: 240 is: 27.18
# total bill for row: 241 is: 22.67
# total bill for row: 242 is: 17.82
# total bill for row: 243 is: 18.78

# %%
# get columns
inner_df = tips_df[['total_bill', "tip"]]
inner_df.head()
# Out:
#    total_bill   tip
# 0       16.99  1.01
# 1       10.34  1.66
# 2       21.01  3.50
# 3       23.68  3.31
# 4       24.59  3.61

# %%
# numpy nd-array
inner_df.values[:5]
# Out:
# array([[16.99,  1.01],
#        [10.34,  1.66],
#        [21.01,  3.5 ],
#        [23.68,  3.31],
#        [24.59,  3.61]])

# %%
# iterate on a dataframe
for total_bill, tip in tips_df[['total_bill', "tip"]].values:
    print(f"whole bill: {total_bill + tip}")
# Out:
# whole bill: 18.0
# whole bill: 12.0
# whole bill: 24.51
# whole bill: 26.99
# whole bill: 28.2
# whole bill: 30.0
# whole bill: 10.77
# whole bill: 30.0
# whole bill: 17.0
# whole bill: 18.009999999999998
# whole bill: 11.98
# whole bill: 40.26
# whole bill: 16.99
# whole bill: 21.43
# whole bill: 17.85
# whole bill: 25.5
# whole bill: 12.0
# whole bill: 20.0
# whole bill: 20.47
# whole bill: 24.0
# whole bill: 22.0
# whole bill: 23.04
# whole bill: 18.0
# whole bill: 47.0
# whole bill: 23.0
# whole bill: 20.15
# whole bill: 15.37
# whole bill: 14.69
# whole bill: 26.0
# whole bill: 22.65
# whole bill: 11.0
# whole bill: 20.85
# whole bill: 18.060000000000002
# whole bill: 23.14
# whole bill: 21.05
# whole bill: 27.66
# whole bill: 18.31
# whole bill: 20.0
# whole bill: 21.0
# whole bill: 36.269999999999996
# whole bill: 18.28
# whole bill: 20.0
# whole bill: 17.0
# whole bill: 11.0
# whole bill: 36.0
# whole bill: 21.29
# whole bill: 27.23
# whole bill: 38.4
# whole bill: 30.6
# whole bill: 21.04
# whole bill: 15.04
# whole bill: 12.889999999999999
# whole bill: 40.010000000000005
# whole bill: 11.5
# whole bill: 29.9
# whole bill: 23.0
# whole bill: 41.01
# whole bill: 27.91
# whole bill: 13.0
# whole bill: 55.0
# whole bill: 23.5
# whole bill: 15.81
# whole bill: 13.0
# whole bill: 22.049999999999997
# whole bill: 20.23
# whole bill: 23.229999999999997
# whole bill: 18.919999999999998
# whole bill: 4.07
# whole bill: 41.73
# whole bill: 26.3
# whole bill: 14.99
# whole bill: 32.06
# whole bill: 31.05
# whole bill: 57.33
# whole bill: 15.77
# whole bill: 34.67
# whole bill: 14.0
# whole bill: 31.15
# whole bill: 13.09
# whole bill: 9.18
# whole bill: 33.230000000000004
# whole bill: 14.36
# whole bill: 16.9
# whole bill: 10.5
# whole bill: 18.98
# whole bill: 15.0
# whole bill: 18.77
# whole bill: 12.09
# whole bill: 23.45
# whole bill: 16.0
# whole bill: 25.0
# whole bill: 26.01
# whole bill: 18.689999999999998
# whole bill: 15.0
# whole bill: 12.24
# whole bill: 18.53
# whole bill: 11.32
# whole bill: 13.6
# whole bill: 34.0
# whole bill: 40.5
# whole bill: 34.95
# whole bill: 29.18
# whole bill: 24.67
# whole bill: 19.57
# whole bill: 21.78

# %% [markdown]
# #### Task
#     Task: Save the total paid money by costumers in a new column

# %%
total_paid = []
for total_bill, tip in tips_df[['total_bill', "tip"]].values:
    total_paid.append(total_bill + tip)
tips_df['total_paid'] = total_paid
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  total_paid
# 0       16.99  1.01  Female     No  Sun  Dinner     2       18.00
# 1       10.34  1.66    Male     No  Sun  Dinner     3       12.00
# 2       21.01  3.50    Male     No  Sun  Dinner     3       24.51
# 3       23.68  3.31    Male     No  Sun  Dinner     2       26.99
# 4       24.59  3.61  Female     No  Sun  Dinner     4       28.20

# %%
# list comprehension usage!
# tips_df['total_paid'] = [total_bill + tip for total_bill, tip in tips_df[['total_bill', "tip"]].values]

# %% [markdown]
# #### Task: Drop
#     Drop the previously created column

# %%
tips_df.drop("total_paid", axis=1)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# total_paid is not dropped?!
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size  total_paid
# 0         16.99  1.01  Female     No   Sun  Dinner     2       18.00
# 1         10.34  1.66    Male     No   Sun  Dinner     3       12.00
# 2         21.01  3.50    Male     No   Sun  Dinner     3       24.51
# 3         23.68  3.31    Male     No   Sun  Dinner     2       26.99
# 4         24.59  3.61  Female     No   Sun  Dinner     4       28.20
# ..          ...   ...     ...    ...   ...     ...   ...         ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3       34.95
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2       29.18
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2       24.67
# 242       17.82  1.75    Male     No   Sat  Dinner     2       19.57
# 243       18.78  3.00  Female     No  Thur  Dinner     2       21.78
#
# [244 rows x 8 columns]

# %% [markdown]
# ### Inplace argument
#     when `inplace` argument is set to True, it means there would be no output and the df will be changed. Otherwise, the modified df is returned but the main df is not modified.
#     One can overwrite main df with the returned modified df, or simply set the inplace argument to True. I, however, prefer the former one :)

# %%
tips_df.drop("total_paid", axis=1, inplace=True)
# or
# tips_df = tips_df.drop("total_paid", axis=1)

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips_df.drop("total_paid", axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [107], in <cell line: 1>()
# ----> 1 tips_df.drop("total_paid", axis=1, inplace=True)
#
# File ~\miniconda3\envs\intro_py\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\miniconda3\envs\intro_py\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File ~\miniconda3\envs\intro_py\lib\site-packages\pandas\core\generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File ~\miniconda3\envs\intro_py\lib\site-packages\pandas\core\generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File ~\miniconda3\envs\intro_py\lib\site-packages\pandas\core\indexes\base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['total_paid'] not found in axis"

# %%
# how to check a column exists in a df
"total_paid" in tips_df
# Out:
# False

# %%
"total_bill" in tips_df
# Out:
# True

# %%
# drop a row/sample
tips_df.drop(0, axis=0)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [243 rows x 7 columns]

# %%
# drop several rows/samples
tips_df.drop([2, 5], axis=0)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [242 rows x 7 columns]

# %% [markdown]
# *:)*
