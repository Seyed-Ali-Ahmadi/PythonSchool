# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('seaborn-whitegrid')
# plt.style.use('bmh')

# %% [markdown]
# ### Draw a line

# %%
# fig = plt.figure()
plt.figure()
plt.plot([4, 2, 3, 6], [1, 2, 3, 4], 'b', label='blue_line')
plt.ylabel('y coordinates')
plt.xlabel('x coordinates')
plt.legend(loc='best')
plt.title('Title')
plt.show()

# %%
help(plt.plot)
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args, scalex=True, scaley=True, data=None, **kwargs)
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], *, data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
# ...

# %% [markdown]
# ### Save a figure

# %%
plt.plot([1,2,3,4], label='blue_line', color='k') # x = range(len(y))
plt.ylabel('some numbers')
plt.legend()
plt.title('title')
plt.savefig('D:/00.University/00.Courses/PythonCourse/KNTU_Course/Data/blue_line.png')

# %%
from IPython.display import Image
Image('D:/00.University/00.Courses/PythonCourse/KNTU_Course/Data/blue_line.png')

# %% [markdown]
# ### Colors, line styles and ...

# %%
x = np.linspace(0, 10, 1000)
plt.plot(x, np.sin(x - 0), color='blue') # specify color by name
plt.plot(x, np.sin(x - 1), color='g') # short color code (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75') # Grayscale between 0 and 1
plt.plot(x, np.sin(x - 3), color='#FFDD44') # Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple, values 0 and 1
plt.plot(x, np.sin(x - 5), color='chartreuse'); # all HTML color names supported

# %%
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted');
# For short, you can use the following codes:
plt.plot(x, x + 4, linestyle='-') # solid
plt.plot(x, x + 5, linestyle='--') # dashed
plt.plot(x, x + 6, linestyle='-.') # dashdot
plt.plot(x, x + 7, linestyle=':'); # dotted

# %%
plt.plot(x, x + 4, 'k--')

# %% [markdown]
# ### Subplot, Subplots

# %%
x = np.linspace(0, 10, 1000)
plt.figure() # create a plot figure
# create the first of two panels and set current axis
plt.subplot(2, 1, 1) # (rows, columns, panel number)
plt.plot(x, np.sin(x))
# create the second panel and set current axis
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x));

# %%
plt.figure(figsize=(10, 5))

plt.subplot(221)
plt.plot([1, 2], [0, 5], 'k')
plt.xlabel('Some numbers')

plt.subplot(222)
plt.plot(x, np.cos(x), ':b', ms=5)
plt.ylabel('Cosine of X')

plt.subplot(223)
plt.plot(np.sin(np.arange(0, 100, 0.1)), label='Sine of 0-100')
plt.xlim([-10, 110])
plt.ylim([-2, 2])
plt.legend()

plt.subplot(224)
plt.plot([0, 1, 2], [9, 6, 3], 'rs')
plt.title('Title of the 4th figure')

plt.tight_layout()
plt.show()

# %%
# First create a grid of plots
# ax will be an array of two Axes objects
fig, ax = plt.subplots(2, 3)
# Call plot() method on the appropriate object
ax[0, 0].plot(x, np.sin(x))
ax[1, 2].plot(x, np.cos(x))
ax[1, 0].plot(x, np.cos(x))

# %% [markdown]
# * plt.xlabel() → ax.set_xlabel()
# * plt.ylabel() → ax.set_ylabel()
# * plt.xlim() → ax.set_xlim()
# * plt.ylim() → ax.set_ylim()
# * plt.title() → ax.set_title()

# %% [markdown]
# ### scatter plots
# #### plt.plot

# %%
plt.figure(figsize=(7, 7))
plt.plot([1,2,3,4], [1,4,9,16], 'b*', ms=9)
plt.plot([1,2,3,4], [1,4,9,16], 'o', mfc='none', mec='k', ms=10)
# plt.axis([0,6,0,20])
plt.xlim([0, 6])
plt.ylim([0, 20])

plt.xticks(ticks=[1, 2, 3, 4], labels=['ali', 'hassan', 'zahra', 'samira'])
plt.show()

# %%
x = np.linspace(0, 10, 30)
y = np.sin(x)
plt.plot(x, y, ':sk'); # line (-), circle marker (o), black (k)
plt.plot(x, y+0.7, '-->r'); # line (-), circle marker (o), black (k)

# %% [markdown]
# #### plt.scatter
#
#     The primary difference of plt.scatter from plt.plot is that it can be used to create
#     scatter plots where the properties of each individual point (size, face color, edge color,
#     etc.) can be individually controlled or mapped to data.

# %%
plt.plot(x, y, 'r')
plt.scatter(x, y, color='k', marker='p')

# %%
rng = np.random.RandomState(np.random.randint(100))
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)
plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, edgecolors='k', cmap='hsv')
plt.colorbar(); # show color scale

# %% [markdown]
# ### Charts

# %% [markdown]
# #### Bar Chart

# %%
# Bar chart
data = [25., 5., 150., 100.] 
x_values = range(len(data)) 
plt.bar(x_values, data, edgecolor='k', linewidth=2, facecolor='gold', width=0.3, alpha=0.95)
plt.grid(True, ls='--', color='gray', alpha=0.3)
plt.show()

# %%
# Multiple bar charts
data = [
[8., 57., 22., 10.], [16., 7., 32., 40.],
]
import numpy as np 
x_values = np.arange(4)
plt.bar(x_values + 0.00, data[0], color='c', width=0.30) 
plt.bar(x_values + 0.30, data[1], color='k', width=0.30)
plt.show()

# %% [markdown]
# #### histograms

# %%
data = np.random.randn(1000)
plt.hist(data, edgecolor='r', facecolor='g')
# Out:
# (array([  3.,   9.,  57., 154., 314., 282., 131.,  44.,   5.,   1.]),
#  array([-3.86636027, -3.07908559, -2.29181092, -1.50453625, -0.71726157,
#          0.0700131 ,  0.85728777,  1.64456245,  2.43183712,  3.2191118 ,
#          4.00638647]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data, bins=50, density=True, alpha=0.7, histtype='stepfilled', color='steelblue',edgecolor='none');

# %%
Image('hist.png')

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)
kwargs = dict(histtype='stepfilled', alpha=0.3, density=True, bins=40)
plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs)
plt.savefig('hist.png')

# %% [markdown]
# #### The Box plot

# %%
help(plt.boxplot)
# Out:
# Help on function boxplot in module matplotlib.pyplot:
#
# boxplot(x, notch=None, sym=None, vert=None, whis=None, positions=None, widths=None, patch_artist=None, bootstrap=None, usermedians=None, conf_intervals=None, meanline=None, showmeans=None, showcaps=None, showbox=None, showfliers=None, boxprops=None, labels=None, flierprops=None, medianprops=None, meanprops=None, capprops=None, whiskerprops=None, manage_ticks=True, autorange=False, zorder=None, *, data=None)
#     Draw a box and whisker plot.
#
#     The box extends from the first quartile (Q1) to the third
#     quartile (Q3) of the data, with a line at the median.  The
#     whiskers extend from the box by 1.5x the inter-quartile range
#     (IQR).  Flier points are those past the end of the whiskers.
#     See https://en.wikipedia.org/wiki/Box_plot for reference.
#
#     .. code-block:: none
#
#               Q1-1.5IQR   Q1   median  Q3   Q3+1.5IQR
#                            |-----:-----|
# ...

# %%
data = np.random.randn(50)
plt.boxplot(data, showfliers=True, showcaps=True, showmeans=True)
plt.show()

# %% [markdown]
# ####  Pie chart

# %%
data = [500, 200, 250]
labels = ["Agriculture", "Aide", "News"]
plt.pie(data, labels=labels,autopct='%1.1f%%') 
plt.show()

# %% [markdown]
# #### Bubble chart

# %%
n = 10
x = np.random.rand(n) 
y = np.random.rand(n) 
colors = np.random.rand(n)
area = np.pi * (60 * np.random.rand(n)) ** 2
plt.scatter(x, y, s=area, c=colors, alpha=0.5);

# %% [markdown]
# ### Working with text

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
np.random.seed(19680801)

mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, density=1, facecolor='g', alpha=0.5)


plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %% [markdown]
# ### Annotating text

# %%
import numpy as np
import matplotlib.pyplot as plt

ax = plt.subplot(111)

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = plt.plot(t, s, lw=2)

plt.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
            arrowprops=dict(facecolor='black'),)

plt.ylim(-2,2)
plt.show()

# %% [markdown]
# ### Logarithmic and other nonlinear axes

# %%
import numpy as np
import matplotlib.pyplot as plt

from matplotlib.ticker import NullFormatter  # useful for `logit` scale

# Fixing random state for reproducibility
np.random.seed(19680801)

# make up some data in the interval ]0, 1[
y = np.random.normal(loc=0.5, scale=0.4, size=1000)
y = y[(y > 0) & (y < 1)]
y.sort()
x = np.arange(len(y))

# plot with various axes scales
plt.figure(1)

# linear
plt.subplot(221)
plt.plot(x, y)
plt.yscale('linear')
plt.title('linear')
plt.grid(True)


# log
plt.subplot(222)
plt.plot(x, y)
plt.yscale('log')
plt.title('log')
plt.grid(True)

# symmetric log
plt.subplot(223)
plt.plot(x, y - y.mean())
plt.yscale('symlog', )
plt.title('symlog')
plt.grid(True)

# logit
plt.subplot(224)
plt.plot(x, y)
plt.yscale('logit')
plt.title('logit')
plt.grid(True)
# Format the minor tick labels of the y-axis into empty strings with
# `NullFormatter`, to avoid cumbering the axis with too many labels.
plt.gca().yaxis.set_minor_formatter(NullFormatter())
# Adjust the subplot layout, because the logit one may take more space
# than usual, due to y-tick labels like "1 - 10^{-3}"
plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.25,
                    wspace=0.35)

plt.show()

# %% [markdown]
# *:)*
